# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/basket_analysis.csv')


df = df.drop('Unnamed: 0', axis = 1)
df
# Out:
#      Apple  Bread  Butter  Cheese  ...  Sugar  Unicorn  Yogurt  chocolate
# 0    False   True   False   False  ...   True    False    True       True
# 1    False  False   False   False  ...  False    False   False      False
# 2     True  False    True   False  ...  False    False    True       True
# 3    False  False    True    True  ...  False    False   False      False
# 4     True   True   False   False  ...  False    False   False      False
# ..     ...    ...     ...     ...  ...    ...      ...     ...        ...
# 994  False   True   False   False  ...  False     True   False       True
# 995   True  False   False   False  ...  False    False    True      False
# 996   True  False   False   False  ...   True    False   False       True
# 997  False  False    True    True  ...   True    False    True       True
# 998  False  False   False   False  ...  False    False   False       True
#
# [999 rows x 16 columns]

# %%
frequent_itemsets = apriori(df, min_support=0.1, use_colnames = True)

# %%
frequent_itemsets
# Out:
#       support                        itemsets
# 0    0.383383                         (Apple)
# 1    0.384384                         (Bread)
# 2    0.420420                        (Butter)
# 3    0.404404                        (Cheese)
# 4    0.407407                          (Corn)
# ..        ...                             ...
# 164  0.101101  (chocolate, Ice cream, Nutmeg)
# 165  0.101101   (Onion, Ice cream, chocolate)
# 166  0.100100    (Milk, Kidney Beans, Nutmeg)
# 167  0.101101  (Kidney Beans, Yogurt, Nutmeg)
# 168  0.104104       (Milk, Yogurt, chocolate)
#
# [169 rows x 2 columns]

# %%
association_rules(frequent_itemsets, metric = 'lift', min_threshold=1)
# Out:
#              antecedents          consequents  ...  leverage  conviction
# 0                (Bread)              (Apple)  ...  0.006788    1.029482
# 1                (Apple)              (Bread)  ...  0.006788    1.029610
# 2                (Apple)             (Butter)  ...  0.027006    1.138354
# 3               (Butter)              (Apple)  ...  0.027006    1.116289
# 4               (Cheese)              (Apple)  ...  0.007120    1.029393
# ..                   ...                  ...  ...       ...         ...
# 431    (Milk, chocolate)             (Yogurt)  ...  0.015307    1.142909
# 432  (Yogurt, chocolate)               (Milk)  ...  0.023753    1.252444
# 433               (Milk)  (Yogurt, chocolate)  ...  0.023753    1.078836
# 434             (Yogurt)    (Milk, chocolate)  ...  0.015307    1.048390
# 435          (chocolate)       (Milk, Yogurt)  ...  0.023954    1.075489
#
# [436 rows x 9 columns]
